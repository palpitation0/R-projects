# %% [markdown]
# <a href="https://colab.research.google.com/github/palpitation0/R-projects/blob/master/EDA%20with%20Kozi's%20data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7e276f8d-2ea4-4ed3-b0fc-f79b4a8324df" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7e276f8d-2ea4-4ed3-b0fc-f79b4a8324df">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving PA VSD data.csv to PA VSD data (2).csv

# %%
df = pd.read_csv('PA VSD data (2).csv')
df.head()
# Out:
#          ID  VSD size MPA size  ...   PDA  op_final Unnamed: 17
# 0  47327588       3.7     5.29  ...  2.00     shunt         NaN
# 1  48058436       3.3        2  ...  4.40  Rastelli         NaN
# 2  47977729       6.0     5.68  ...  3.50  Rastelli         NaN
# 3  48188089       5.8     1.76  ...  3.13     shunt         NaN
# 4  48273026       7.0      4.4  ...  5.00     shunt         NaN
#
# [5 rows x 18 columns]

# %%
df.describe()
# Out:
#                  ID   VSD size  ...          EFW        PDA
# count  3.600000e+01  36.000000  ...    36.000000  33.000000
# mean   5.053241e+07   4.357778  ...  2826.805556   3.734848
# std    4.974592e+06   1.563825  ...   719.455303   0.994708
# min    2.457128e+07   1.900000  ...  1220.000000   1.900000
# 25%    4.931443e+07   3.250000  ...  2478.750000   3.100000
# 50%    5.135141e+07   4.400000  ...  2950.000000   3.700000
# 75%    5.293120e+07   5.800000  ...  3315.000000   4.600000
# max    5.498319e+07   7.400000  ...  4330.000000   5.600000
#
# [8 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                36 non-null     int64
#  1   VSD size          36 non-null     float64
#  2   MPA size          36 non-null     object
#  3   MPA size z-score  36 non-null     object
#  4   LPA size          36 non-null     object
#  5   LPA size z-score  35 non-null     object
#  6   RPA size          36 non-null     float64
#  7   RPA size z-score  36 non-null     float64
#  8   Pulmonary supply  36 non-null     int64
#  9   Aortic arch       36 non-null     int64
#  10  ductus            36 non-null     int64
#  11  Cardiac anomaly   36 non-null     int64
#  12  EFW               36 non-null     int64
#  13  MaGoon            26 non-null     object
#  14  Nakata            26 non-null     object
#  15  PDA               33 non-null     float64
# ...

# %%
df.loc[df['op_final'] == 'shunt', 'op_final'] = 1
df.loc[df['op_final'] == 'Rastelli', 'op_final'] = 2
df.head()
# Out:
#          ID  VSD size MPA size  ...   PDA op_final Unnamed: 17
# 0  47327588       3.7     5.29  ...  2.00        1         NaN
# 1  48058436       3.3        2  ...  4.40        2         NaN
# 2  47977729       6.0     5.68  ...  3.50        2         NaN
# 3  48188089       5.8     1.76  ...  3.13        1         NaN
# 4  48273026       7.0      4.4  ...  5.00        1         NaN
#
# [5 rows x 18 columns]

# %%
del df['Unnamed: 17']
df.head()
# Out:
#          ID  VSD size MPA size MPA size z-score  ... MaGoon  Nakata   PDA  op_final
# 0  47327588       3.7     5.29             0.29  ...   1.38  122.56  2.00         1
# 1  48058436       3.3        2            -6.33  ...   1.66     248  4.40         2
# 2  47977729       6.0     5.68             0.32  ...   1.61  155.17  3.50         2
# 3  48188089       5.8     1.76            -6.68  ...   1.28  153.46  3.13         1
# 4  48273026       7.0      4.4            -4.49  ...    NaN     NaN  5.00         1
#
# [5 rows x 17 columns]

# %%
df1 = df.drop(df.columns[[1, 2, 4, 6]], axis='columns')
df1.head()
# Out:
#          ID MPA size z-score LPA size z-score  ...  Nakata   PDA  op_final
# 0  47327588             0.29                n  ...  122.56  2.00         1
# 1  48058436            -6.33            -1.75  ...     248  4.40         2
# 2  47977729             0.32             0.38  ...  155.17  3.50         2
# 3  48188089            -6.68            -2.39  ...  153.46  3.13         1
# 4  48273026            -4.49            -1.12  ...     NaN  5.00         1
#
# [5 rows x 13 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                36 non-null     int64
#  1   MPA size z-score  36 non-null     object
#  2   LPA size z-score  35 non-null     object
#  3   RPA size z-score  36 non-null     float64
#  4   Pulmonary supply  36 non-null     int64
#  5   Aortic arch       36 non-null     int64
#  6   ductus            36 non-null     int64
#  7   Cardiac anomaly   36 non-null     int64
#  8   EFW               36 non-null     int64
#  9   PDA               33 non-null     float64
#  10  op_final          36 non-null     object
# dtypes: float64(2), int64(6), object(3)
# memory usage: 3.2+ KB

# %%
df3 = df2.drop(df2.columns[[1,2]], axis='columns')

# %%
df3["op_final"]=df3["op_final"].astype(int)
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                36 non-null     int64
#  1   RPA size z-score  36 non-null     float64
#  2   Pulmonary supply  36 non-null     int64
#  3   Aortic arch       36 non-null     int64
#  4   ductus            36 non-null     int64
#  5   Cardiac anomaly   36 non-null     int64
#  6   EFW               36 non-null     int64
#  7   PDA               33 non-null     float64
#  8   op_final          36 non-null     int64
# dtypes: float64(2), int64(7)
# memory usage: 2.7 KB

# %%
interpolate = df3.interpolate(method='values')
interpolate.head()
# Out:
#          ID  RPA size z-score  Pulmonary supply  ...   EFW   PDA  op_final
# 0  47327588              0.30                 1  ...  3400  2.00         1
# 1  48058436             -1.55                 1  ...  2780  4.40         2
# 2  47977729              1.74                 1  ...  2170  3.50         2
# 3  48188089             -0.68                 1  ...  3420  3.13         1
# 4  48273026             -1.23                 5  ...  3360  5.00         1
#
# [5 rows x 9 columns]

# %%
interpolate.corr()
# Out:
#                         ID  RPA size z-score  ...       PDA  op_final
# ID                1.000000         -0.042340  ... -0.142220 -0.045912
# RPA size z-score -0.042340          1.000000  ... -0.238084  0.206308
# Pulmonary supply  0.011183         -0.139946  ...  0.018984 -0.140028
# Aortic arch      -0.014540         -0.257910  ...  0.209057 -0.185185
# ductus           -0.050606         -0.135874  ...  0.333164 -0.218218
# Cardiac anomaly  -0.018228         -0.041496  ...  0.016422 -0.086066
# EFW              -0.037315          0.347722  ...  0.102273 -0.001017
# PDA              -0.142220         -0.238084  ...  1.000000  0.089113
# op_final         -0.045912          0.206308  ...  0.089113  1.000000
#
# [9 rows x 9 columns]

# %%
import matplotlib.pyplot as plt 
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
plt.figure(figsize=(15,15))
sns.heatmap(data = interpolate.corr(), annot=True, 
fmt = '.2f', linewidths=.5, cmap='Blues')

# %%
sns.pairplot(interpolate, diag_kind='hist')
plt.show()

# %%
sns.pairplot(interpolate, diag_kind='kde', hue="op_final", palette='bright')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
